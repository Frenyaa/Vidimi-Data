# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
pd.options.display.float_format = '{:.0f}'.format

# %% [markdown]
# ---
# 1.Nhập dữ liệu vào
# ---

# %%
import pandas as pd

# Assuming the file is a CSV or similar format that pandas can read directly from the Drive path
file_path = '/content/drive/MyDrive/Vidimi/Data Raw/bill_output.xlsx'

# You might need to adjust the read function based on the actual file type
try:
    df = pd.read_excel(file_path)
    display(df.head())
except Exception as e:
    print(f"Error reading file: {e}")
    print("Please check the file path and ensure the file is in a format pandas can read directly.")
# Out:
# Error reading file: [Errno 2] No such file or directory: '/content/drive/MyDrive/Vidimi/Data Raw/bill_output.xlsx'
# Please check the file path and ensure the file is in a format pandas can read directly.

# %% [markdown]
# ---
# 2.EDA
# ---

# %% [markdown]
# 2.1.Tổng quan bộ dữ liệu
# --

# %%
import pandas as pd

def general_eda(df):
    print("--- DataFrame Shape ---")
    display(df.shape)

    print("\n--- Descriptive Statistics ---")
    display(df.describe())

    print("\n--- DataFrame Info ---")
    df.info()

    print("\n--- Missing Values ---")
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * mis_val / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table.columns = ['Missing Values', '% of Total Values']
    mis_val_table_filtered = (
        mis_val_table[mis_val_table['Missing Values'] > 0]
        .sort_values('% of Total Values', ascending=False)
        .round(1)
    )

    print(f"There are {mis_val_table_filtered.shape[0]} columns that have missing values.")

    no_missing_cols = mis_val_table[mis_val_table['Missing Values'] == 0].index.tolist()

    if no_missing_cols:
        print("Columns with no missing values:", ", ".join(no_missing_cols))
    else:
        print("No columns are completely free of missing values.")

    display(mis_val_table_filtered)


    print("\n--- Duplicate Rows ---")
    dup_val = df.duplicated().sum()
    dup_val_percent = 100 * dup_val / len(df)
    print(f"Number of duplicate rows: {dup_val}")
    print(f"Percentage of duplicate rows: {dup_val_percent:.2f}%")
    if dup_val > 0:
        print("\nDuplicate rows (first 5):")
        display(df[df.duplicated(keep=False)].head())

# %%
df.shape

# %%
df.describe()

# %%
display(df[['Item Number', 'Item Price']].describe())

# %%
df.info()

# %%
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        # Filter the missing_values table to show columns with 0 missing values
        no_missing_values = missing_values[missing_values['Missing Values'] == 0]
        display(no_missing_values)
        return mis_val_table_ren_columns

missing_values = missing_values_table(df)
display(missing_values)

# %%
import pandas as pd

def missing_values_table(df):
    # Tính số lượng và tỷ lệ missing values
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * mis_val / len(df)

    # Gộp hai cột lại thành bảng
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table.columns = ['Missing Values', '% of Total Values']

    # Lọc các cột có missing values > 0
    mis_val_table_filtered = (
        mis_val_table[mis_val_table['Missing Values'] > 0]
        .sort_values('% of Total Values', ascending=False)
        .round(1)
    )

    print(
        f"Your selected dataframe has {df.shape[1]} columns.\n"
        f"There are {mis_val_table_filtered.shape[0]} columns that have missing values."
    )

    # Lọc các cột không có missing values
    no_missing_cols = mis_val_table[mis_val_table['Missing Values'] == 0].index.tolist()

    if no_missing_cols:
        print("\nCột không bị missing value:", ", ".join(no_missing_cols))
    else:
        print("\nKhông có cột nào đầy đủ dữ liệu (tất cả đều có missing value).")

    print("\nBảng các cột có missing value:")
    display(mis_val_table_filtered)

    return mis_val_table_filtered

# Gọi hàm
missing_values = missing_values_table(df)

# %%
dup_val = df.duplicated().sum()
dup_val_percent = 100 * dup_val / len(df)
print(f"Number of duplicate rows: {dup_val}")
print(f"Percentage of duplicate rows: {dup_val_percent:.2f}%")
duplicate_rows = df[df.duplicated(keep=False)]
display(duplicate_rows)

# %% [markdown]
# 2.2.Kiểm tra loại dữ liệu của các trường dữ liệu

# %%
df.columns
